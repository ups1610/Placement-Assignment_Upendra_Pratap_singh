# %%
# import useful libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# A pharmaceutical company is developing a drug that is supposed to reduce blood pressure.
#
# They conduct a clinical trial with 100 patients and record their blood pressure before and after taking the drug.
#
# The company wants to know if the change in blood pressure follows a normal distribution.
#
# https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_

# %%
# load data from google drive
url = 'https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
df.head()
# Out:
#    Patient ID   Blood Pressure Before (mmHg)   Blood Pressure After (mmHg)
# 0           1                            130                           120
# 1           2                            142                           135
# 2           3                            120                           118
# 3           4                            135                           127
# 4           5                            148                           140

# %%
# step-1 plot a histograph 
sns.displot(df[' Blood Pressure Before (mmHg)'],kde =True)
sns.displot(df[' Blood Pressure After (mmHg)'],kde=True)

# %%
# now plotting a Q-Q plot
import statsmodels.api as sm
import pylab as py
data_points_1 = df[' Blood Pressure Before (mmHg)']  
data_points_2 = df[' Blood Pressure After (mmHg)']   
sm.qqplot(data_points_1,line='45')
sm.qqplot(data_points_2,line='45')
py.show()

# %%
# shapiro test

from scipy import stats
my_data_1 = df[' Blood Pressure Before (mmHg)']
my_data_2 = df[' Blood Pressure After (mmHg)']
corr_1,p_value_1 = stats.shapiro(my_data_1)
corr_2,p_value_2 = stats.shapiro(my_data_2)

if p_value_1 < 0.05:
    print("Blood Pressure Before is not normally distributed")
else:
    print("Blood Pressure After is normally distributed")    
print('-'*20)

if p_value_2 < 0.05:
    print("Blood Pressure After is not normally distributed")
else:
    print("Blood Pressure After is normally distributed")
# Out:
# Blood Pressure Before is not normally distributed
# --------------------
# Blood Pressure After is not normally distributed

# %%
# change in Blood Pressure 
chnage_pressure = df[' Blood Pressure After (mmHg)'] - df[ ' Blood Pressure Before (mmHg)']

# perform shapiro test
corr_,p_value = stats.shapiro(chnage_pressure)
if p_value < 0.05:
    print("Change in Blood Pressure are not normally distributed")
else:
    print("Change in Blood Pressure are normally distributed")
# Out:
# Change in Blood Pressure are not normally distributed
